# %% [markdown]
# ## A First Look at Neural Networks

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# The machine learning paradigm is one where you have data, that data is labeled, and you want to figure out the rules that match the data to the labels.
# Consider these two sets of Numpy arrays:

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# When using TensorFlow, we define our layers using `Sequential`.

# %%
model = Sequential([Dense(units=1, input_shape=[1])])
# Out:
# 2022-02-06 15:50:42.838963: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Inside the `Sequential`, we specify what each layer looks like. Since we have only one line inside our `Sequential`, we have only one layer.
# We then define what the layer look like using the `keras.layers`. `Dense` means a set of fully connected neurons. There are lots of different layer types besides `Dense`.
# Our `Dense` layer has `units=1` specified: So we have just one dense layer with one neuron in our entire neural network.
#
# In the next line we set our optimizer. The fundamental trick in deep learning is to use a loss function or cost function as a feedback signal to adjust the value of the weights a little, in a direction that will lower the loss score for the current example. It implements what’s called the Backpropagation algorithm: the central algorithm in deep learning.
#
# `sgd` stands for *stochastic gradient descent*. A training loop, which, repeated a sufficient number of times, yields weight values that minimize the loss function. Of course, there are other kinds of optimizer. We need just to pick the appropriate one to use for different scenarios.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# The learning process will then begin with the command `model.fit`:

# %%
model.fit(xs, ys, epochs=500);
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 706ms/step - loss: 1.0803
# Epoch 2/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9787
# Epoch 3/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.8961
# Epoch 4/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8286
# Epoch 5/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7729
# Epoch 6/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7266
# Epoch 7/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6877
# Epoch 8/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6548
# Epoch 9/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6265
# Epoch 10/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.6020
# Epoch 11/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5805
# Epoch 12/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5613
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.986403]]

# %%
print("Here is what I learned: {}".format(model.get_weights()))
# Out:
# Here is what I learned: [array([[1.9980291]], dtype=float32), array([-0.99388963], dtype=float32)]

# %% [markdown]
# The model only has a single neuron in it, and that neuron learns a *weight* and a *bias*, so that Y = WX + B.
# Thus, the learned relationship between X and Y was Y = 1.9967953X – 0.9900647. The correct answer would be Y = 2X - 1. It is pretty close. Given that the model was trained on only six items of data, the answer could never be expected to be exactly the exact right vales, but something very close to them.
